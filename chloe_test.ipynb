# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import scipy.stats as stats
import openpyxl 
import distribution as dist

# %%
# dfU = pd.read_csv('updatedData.csv')
# dfU.head()
dfU = pd.read_excel('access.xlsx', index_col=11) 
dfU.head()
# Out:
#                                                       Unnamed: 0  \
# Density of nursing and midwifery personnelw (pe...           NaN
# Primary data                                           Data type
# NaN                                                          NaN
# 2012-2020                                           Member State
# 4.5                                                  Afghanistan
#
#                                                                                                   3.a  \
# Density of nursing and midwifery personnelw (pe...  Age-standardized prevalence of tobacco use amo...
# Primary data                                                                     Comparable estimates
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                              23.3
#
#                                                    Unnamed: 2  \
# Density of nursing and midwifery personnelw (pe...        NaN
# Primary data                                              NaN
# NaN                                                       NaN
# 2012-2020                                                 NaN
# 4.5                                                       NaN
#
#                                                                                                   3.b  \
# Density of nursing and midwifery personnelw (pe...  Diphtheria-tetanus-pertussis (DTP3) immunizati...
# Primary data                                                                     Comparable estimates
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                                70
#
#                                                                                            Unnamed: 4  \
# Density of nursing and midwifery personnelw (pe...  Measles-containing-vaccine second-dose (MCV2) ...
# Primary data                                                                     Comparable estimates
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                                43
#
#                                                                                            Unnamed: 5  \
# Density of nursing and midwifery personnelw (pe...  Pneumococcal conjugate 3rd dose (PCV3) immuniz...
# Primary data                                                                     Comparable estimates
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                                68
#
#                                                                                            Unnamed: 6  \
# Density of nursing and midwifery personnelw (pe...  Human papillomavirus (HPV) immunization covera...
# Primary data                                                                     Comparable estimates
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                                 -
#
#                                                                                            Unnamed: 7  \
# Density of nursing and midwifery personnelw (pe...  Total net official development assistance to m...
# Primary data                                                                             Primary data
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                              6.15
#
#                                                                                            Unnamed: 8  \
# Density of nursing and midwifery personnelw (pe...  Proportion of health facilities with a core se...
# Primary data                                                                             Primary data
# NaN                                                                                               NaN
# 2012-2020                                                                                   2012-2019
# 4.5                                                                                                 -
#
#                                                    Unnamed: 9  \
# Density of nursing and midwifery personnelw (pe...        NaN
# Primary data                                              NaN
# NaN                                                       NaN
# 2012-2020                                                 NaN
# 4.5                                                       NaN
#
#                                                                                                   3.c  \
# Density of nursing and midwifery personnelw (pe...  Density of medical doctorsw (per 10 000 popula...
# Primary data                                                                             Primary data
# NaN                                                                                               NaN
# 2012-2020                                                                                   2012-2020
# 4.5                                                                                               2.5
#
#                                                                                       Unnamed: 12  \
# Density of nursing and midwifery personnelw (pe...  Density of dentistsw (per 10 000 population)
# Primary data                                                                         Primary data
# NaN                                                                                           NaN
# 2012-2020                                                                               2012-2020
# 4.5                                                                                           0.7
#
#                                                                                          Unnamed: 13  \
# Density of nursing and midwifery personnelw (pe...  Density of pharmacistsw (per 10 000 population)
# Primary data                                                                            Primary data
# NaN                                                                                              NaN
# 2012-2020                                                                                  2012-2020
# 4.5                                                                                              0.3
#
#                                                                                                   3.d  \
# Density of nursing and midwifery personnelw (pe...  Average of 13 International Health Regulations...
# Primary data                                                                             Primary data
# NaN                                                                                               NaN
# 2012-2020                                                                                        2021
# 4.5                                                                                                41
#
#                                                                                           Unnamed: 15  \
# Density of nursing and midwifery personnelw (pe...  Proportion of bloodstream infections due methi...
# Primary data                                                                             Primary data
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                                 -
#
#                                                                                           Unnamed: 16  \
# Density of nursing and midwifery personnelw (pe...  Proportion of bloodstream infection due to Esc...
# Primary data                                                                             Primary data
# NaN                                                                                               NaN
# 2012-2020                                                                                        2020
# 4.5                                                                                                 -
#
#                                                                                                   1.a  \
# Density of nursing and midwifery personnelw (pe...  Domestic general government health expenditure...
# Primary data                                                                     Comparable estimates
# NaN                                                                                               NaN
# 2012-2020                                                                                        2019
# 4.5                                                                                               3.9
#
#                                                      Unnamed: 18
# Density of nursing and midwifery personnelw (pe...           NaN
# Primary data                                                 NaN
# NaN                                                          NaN
# 2012-2020                                           Member State
# 4.5                                                  Afghanistan

# %%
dfU_only_female = dfU[dfU["Gender"] == "FEMALE"]
dfU_only_female.head()
# Out:
#    Unnamed: 0    Patient_ID   Age  Gender  Protein1  Protein2  Protein3  \
# 0           0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715
# 1           1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447
# 2           2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747
# 3           3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304
# 4           4  TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045
#
#    Protein4 Tumour_Stage                      Histology ER status PR status  \
# 0  0.273680          III  Infiltrating Ductal Carcinoma  Positive  Positive
# 1 -0.031505           II             Mucinous Carcinoma  Positive  Positive
# 2 -0.234260          III  Infiltrating Ductal Carcinoma  Positive  Positive
# 3  0.124270           II  Infiltrating Ductal Carcinoma  Positive  Positive
# 4 -0.311990           II  Infiltrating Ductal Carcinoma  Positive  Positive
#
#   HER2 status                 Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# 0    Negative  Modified Radical Mastectomy       15-Jan-17          19-Jun-17
# 1    Negative                   Lumpectomy       26-Apr-17          09-Nov-18
# 2    Negative                        Other       08-Sep-17          09-Jun-18
# 3    Negative  Modified Radical Mastectomy       25-Jan-17          12-Jul-17
# 4    Negative                        Other       06-May-17          27-Jun-19
#
#   Patient_Status
# 0          Alive
# 1           Dead
# 2          Alive
# 3          Alive
# 4           Dead

# %%
stage_map = {"I" : 1, "II" : 2, "III" : 3}
dfU['Stage'] = dfU['Tumour_Stage'].map(stage_map)
dfU.head(1)
# Out:
#    Unnamed: 0    Patient_ID   Age  Gender  Protein1  Protein2  Protein3  \
# 0           0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715
#
#    Protein4 Tumour_Stage                      Histology ER status PR status  \
# 0   0.27368          III  Infiltrating Ductal Carcinoma  Positive  Positive
#
#   HER2 status                 Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# 0    Negative  Modified Radical Mastectomy       15-Jan-17          19-Jun-17
#
#   Patient_Status  Stage
# 0          Alive      3

# %%
plt.scatter(dfU["Stage"], dfU["Protein1"], linestyle="None")
plt.show()

# %%
sns.scatterplot(data = dfU, x = "Stage", y = "Protein1")
plt.show()

# %%
sns.scatterplot(data = dfU, x = "Stage", y = "Protein1", color="blue", alpha=0.5)
sns.scatterplot(data = dfU, x = "Stage", y = "Protein2", color="red", alpha=0.5)
sns.scatterplot(data = dfU, x = "Stage", y = "Protein3", color="green", alpha=0.5)
sns.scatterplot(data = dfU, x = "Stage", y = "Protein4", color="orange", alpha=0.5)
# Out:
# <AxesSubplot: xlabel='Stage', ylabel='Protein1'>

# %%
fig, axes = plt.subplots(2,2)
sns.set(rc={'figure.figsize':(20,15)})
sns.scatterplot(ax = axes[0,0], data = dfU, x = "Stage", y = "Protein1", color = "blue", alpha = 0.1)
sns.scatterplot(ax = axes[0,1], data = dfU, x = "Stage", y = "Protein2", color = "orange", alpha=0.1)
sns.scatterplot(ax = axes[1,0], data = dfU, x = "Stage", y = "Protein3", color = "purple", alpha=0.1)
sns.scatterplot(ax = axes[1,1], data = dfU, x = "Stage", y = "Protein4", color = "green", alpha=0.1)
sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})

# %%
df_health = pd.read_csv('health_spending.csv')
df_health.head()
# Out:
#   LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  TIME     Value Flag Codes
# 0      AUS  HEALTHEXP     TOT  USD_CAP         A  2018  5193.845        NaN
# 1      AUS  HEALTHEXP     TOT  USD_CAP         A  2019  5130.234        NaN
# 2      AUS  HEALTHEXP     TOT  USD_CAP         A  2020  5627.315          E
# 3      AUT  HEALTHEXP     TOT  USD_CAP         A  2018  5518.538        NaN
# 4      AUT  HEALTHEXP     TOT  USD_CAP         A  2019  5624.014        NaN

# %%
df_wait_time = pd.read_csv('waittime.csv')

df_wait_time.head()
# Out:
#         VAR          Variable      UNIT  \
# 0  WAITKNEW  Knee replacement  WTSPMDMT
# 1  WAITKNEW  Knee replacement  WTSPMDMT
# 2  WAITKNEW  Knee replacement  WTSPMDMT
# 3  WAITKNEW  Knee replacement  WTSPMDMT
# 4  WAITKNEW  Knee replacement  WTSPMDMT
#
#                                              Measure  COU    Country   YEA  \
# 0  Waiting times from specialist assessment to tr...  AUS  Australia  2010
# 1  Waiting times from specialist assessment to tr...  AUS  Australia  2011
# 2  Waiting times from specialist assessment to tr...  AUS  Australia  2012
# 3  Waiting times from specialist assessment to tr...  AUS  Australia  2013
# 4  Waiting times from specialist assessment to tr...  AUS  Australia  2014
#
#    Year  Value Flag Codes                      Flags
# 0  2010  173.0          D  Difference in methodology
# 1  2011  184.0          D  Difference in methodology
# 2  2012  196.0          D  Difference in methodology
# 3  2013  194.0          D  Difference in methodology
# 4  2014  191.0          D  Difference in methodology

# %%
website = "https://restcountries.com/v3.1/alpha/"

response = requests.get("https://restcountries.com/v3.1/alpha/AUS")
country_name = response.json()[0]['name']['common']

# %%
def get_country_name(in_df):

    code = in_df["LOCATION"]
    website = "https://restcountries.com/v3.1/alpha/" + code

    response = requests.get(website)
    country_name = response.json()[0]['name']['common']

    return country_name

# %%
new_df = pd.DataFrame()

# %%
# df_health['Country'] = df_health.apply(get_country_name, axis=1)

# df_health.head()

# %%
# mini_df_health = df_health[["LOCATION", "Country","TIME", "Value"]]

# mini_df_health.head()

# %%
mini_df_wait_time = df_wait_time[["Variable", "COU", "Country", "YEA", "Year", "Value"]]

mini_df_wait_time.head()
# Out:
#            Variable  COU    Country   YEA  Year  Value
# 0  Knee replacement  AUS  Australia  2010  2010  173.0
# 1  Knee replacement  AUS  Australia  2011  2011  184.0
# 2  Knee replacement  AUS  Australia  2012  2012  196.0
# 3  Knee replacement  AUS  Australia  2013  2013  194.0
# 4  Knee replacement  AUS  Australia  2014  2014  191.0

# %%
life_exp_df = pd.read_csv("Life_Expectancy_Data.csv")

life_exp_df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
mini_life_exp_df = life_exp_df[["Country", "Year", "Life expectancy ", "Adult Mortality", "infant deaths"]]

mini_life_exp_df = mini_life_exp_df[mini_life_exp_df['Life expectancy '].notna()]

mini_life_exp_df.head()

life_exp_mean = mini_life_exp_df[["Life expectancy "]].mean().item()
life_exp_std = mini_life_exp_df[["Life expectancy "]].std().item()

print("Life Expectancy")
print("Mean: " + str(life_exp_mean))
print("Std: " + str(life_exp_std))
print("")

life_exp_bottom_range = int(life_exp_mean - life_exp_std)
life_exp_top_range = int(life_exp_mean + life_exp_std)

print("Range from [" + str(life_exp_bottom_range) + "," + str(life_exp_top_range) + "] years")
# Out:
# Life Expectancy
# Mean: 69.22493169398908
# Std: 9.523867487824301
#
# Range from [59,78] years

# %%
pdf = stats.norm.pdf(mini_life_exp_df["Life expectancy "].sort_values(), life_exp_mean, life_exp_std)

plt.plot(mini_life_exp_df["Life expectancy "].sort_values(), pdf)
plt.xlim([30,110])  
plt.xlabel("Life Expectancy", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
column = "Life expectancy "

mean, std = dist.dist_info(mini_life_exp_df, column)

dist.dist_plot(mini_life_exp_df, column, mean, std, 30, 120)

mini_life_exp_df = dist.add_norm(mini_life_exp_df, column, "Life Exp Scaled")
mini_life_exp_df.head()
# Out:
# Life expectancy
# Mean: 69.22493169398908
# Std: 9.523867487824301
#        Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  2015              65.0            263.0             62
# 1  Afghanistan  2014              59.9            271.0             64
# 2  Afghanistan  2013              59.9            268.0             66
# 3  Afghanistan  2012              59.5            272.0             69
# 4  Afghanistan  2011              59.2            275.0             71
#
#    Life Exp Scaled
# 0         0.544592
# 1         0.447818
# 2         0.447818
# 3         0.440228
# 4         0.434535
